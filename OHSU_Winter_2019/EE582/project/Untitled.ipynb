# %% [markdown]
# # AutoTune Demonstration
# ### Eric D. Stevens
# ### March 19, 2019

# %%
# data tools
import numpy as np
from scipy.io import wavfile

# presentation tools
import matplotlib.pyplot as plt
import sounddevice as sd

# AutoTune Class
from AutoTune import AutoTune

# %% [markdown]
# ## A simple waveform
#
# ### Original data

# %%
fs, simpleWaveform = wavfile.read('samples/tsweep.wav')

# %%
plt.plot(simpleWaveform[100000:101000])

# %%
sd.play(simpleWaveform)

# %% [markdown]
# ### Make the AutoTune Object

# %%
SimpleWaveform = AutoTune(simpleWaveform, sensitivity=1, min_freq=150, max_freq=600)
# Out:
# (178857,)
# i: 8000 bigL: 144 freq: 288.2352941176471
# i: 16000 bigL: 128 freq: 321.8978102189781
# i: 24000 bigL: 200 freq: 230.89005235602093
# i: 32000 bigL: 152 freq: 297.42489270386267
# i: 40000 bigL: 176 freq: 264.07185628742513
# i: 48000 bigL: 112 freq: 364.4628099173554
# i: 56000 bigL: 112 freq: 364.4628099173554
# i: 64000 bigL: 112 freq: 382.2695035460993
# i: 72000 bigL: 88 freq: 454.63917525773195
# i: 80000 bigL: 128 freq: 370.5882352941176
# i: 88000 bigL: 80 freq: 495.50561797752806
# i: 96000 bigL: 80 freq: 495.50561797752806
# i: 104000 bigL: 136 freq: 347.244094488189
# i: 112000 bigL: 120 freq: 387.76978417266184
# i: 120000 bigL: 120 freq: 366.66666666666663
# i: 128000 bigL: 128 freq: 345.2669039145908
# i: 136000 bigL: 136 freq: 324.4816053511706
# i: 144000 bigL: 152 freq: 302.99812617114304
# i: 152000 bigL: 160 freq: 281.8710052295177
# i: 160000 bigL: 168 freq: 260.6663084363245
# i: 168000 bigL: 184 freq: 239.55555555555557
# i: 176000 bigL: 200 freq: 218.41512832057631
# /Users/Eric/Desktop/OHSU/OHSU_Winter_2019/EE582/project/AutoTune.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   val = (E-2*H)/E
# done!

# %%
plt.plot(SimpleWaveform.real_freq)

# %%
SimpleWaveform.build_output(mod_type='identity')
SimpleWaveform.play()

# %%
SimpleWaveform.build_output(mod_type='constant', freq=200)
SimpleWaveform.play()

# %%
SimpleWaveform.build_output(mod_type='constant', freq=400)
SimpleWaveform.play()

# %%
SimpleWaveform.build_output(mod_type='linear', start_freq=70, end_freq=400)
SimpleWaveform.play()

# %%
SimpleWaveform.build_output(mod_type='vibrato', vib_freq=10, amp=11 )
SimpleWaveform.play()

# %%
SimpleWaveform.build_output(mod_type='note')
SimpleWaveform.play()

# %% [markdown]
# ## Simple Voice

# %%
fs, ahhVoice = wavfile.read('samples/ahh.wav')
sd.play(ahhVoice)

# %%
plt.plot(ahhVoice[30000:32000])

# %%
AhhVoice = AutoTune(ahhVoice, sensitivity=0.05)
# Out:
# (15931,)
# i: 8000 bigL: 336 freq: 127.82608695652172
# i: 16000 bigL: 336 freq: 127.82608695652172
# i: 24000 bigL: 336 freq: 127.82608695652172
# i: 32000 bigL: 344 freq: 125.57597721977737
# i: 40000 bigL: 336 freq: 127.82608695652172
# i: 48000 bigL: 336 freq: 128.0961182994455
# i: 56000 bigL: 336 freq: 128.84462151394425
# i: 64000 bigL: 336 freq: 127.82608695652172
# i: 72000 bigL: 336 freq: 128.36729293463878
# i: 80000 bigL: 336 freq: 129.32551319648096
# i: 88000 bigL: 336 freq: 128.77621449429253
# i: 96000 bigL: 336 freq: 129.60192359070265
# i: 104000 bigL: 336 freq: 129.74057234554692
# i: 112000 bigL: 336 freq: 131.0726830586328
# i: 120000 bigL: 336 freq: 132.14383001906836

# %%
plt.plot(AhhVoice.real_freq)

# %%
sd.play(AhhVoice.wav)

# %%
AhhVoice.build_output('identity')
AhhVoice.play()

# %%
AhhVoice.build_output('note')
AhhVoice.play()

# %%
AhhVoice.build_output('constant', freq=155)
AhhVoice.play()

# %%
AhhVoice.build_output('constant', freq=200)
AhhVoice.play()

# %%
AhhVoice.build_output('linear', start_freq=80, end_freq=200)
AhhVoice.play()

# %%
AhhVoice.build_output('vibrato', vib_freq=6, amp=3)
AhhVoice.play()

# %% [markdown]
# ## Complex Speech
#
#
#
# <H3 align="center">Tom's Diner - Suzanne Vega </H3>
# <img src="presentation/Vega.png" alt="drawing" width="400" align="center"/>

# %%
fs, vega = wavfile.read('presentation/Vega.wav')
sd.play(vega,fs)

# %%
# Out:
# [<matplotlib.lines.Line2D at 0x14c12aac8>,
#  <matplotlib.lines.Line2D at 0x14c12ac18>]

# %%
sd.stop()

# %%
fs, diner = wavfile.read('samples/diner.wav')

# %%
sd.play(diner,fs)
plt.plot(diner[30000:32000])

# %%
Diner = AutoTune(diner, sensitivity=.05, min_freq=180, max_freq=320)
# Out:
# (507150,)
# i: 8000 bigL: 144 freq: 293.4664246823956
# i: 24000 bigL: 144 freq: 326.6666666666667
# i: 32000 bigL: 144 freq: 325.3521126760564
# i: 48000 bigL: 144 freq: 311.16100064143683
# i: 72000 bigL: 144 freq: 324.91627595445414
# i: 112000 bigL: 208 freq: 211.92660550458717
# i: 120000 bigL: 216 freq: 196.00000000000003
# i: 128000 bigL: 200 freq: 217.63122476446839
# i: 136000 bigL: 160 freq: 279.9192152336988
# i: 160000 bigL: 176 freq: 259.273115980759
# i: 168000 bigL: 176 freq: 262.0745542949757
# i: 176000 bigL: 200 freq: 218.21862348178135
# i: 184000 bigL: 192 freq: 224.68735525706344
# i: 192000 bigL: 152 freq: 285.52089464390815
# i: 200000 bigL: 168 freq: 249.92272024729522
# i: 216000 bigL: 192 freq: 230.45130641330164
# i: 224000 bigL: 168 freq: 261.22778675282717
# i: 232000 bigL: 176 freq: 249.40874035989717
# i: 240000 bigL: 192 freq: 222.01372997711672
# i: 248000 bigL: 208 freq: 218.809201623816
# i: 264000 bigL: 176 freq: 242.67133566783394
# i: 272000 bigL: 168 freq: 256.5309360126917
# i: 280000 bigL: 184 freq: 236.74963396778912
# i: 288000 bigL: 192 freq: 220.80109239872553
# i: 296000 bigL: 168 freq: 268.15920398009945
# i: 304000 bigL: 168 freq: 257.6208178438662
# i: 328000 bigL: 208 freq: 207.92970424346336
# i: 336000 bigL: 200 freq: 220.19972764412165
# i: 344000 bigL: 192 freq: 221.40575079872204
# i: 352000 bigL: 152 freq: 284.51612903225805
# i: 360000 bigL: 176 freq: 238.3783783783784
# i: 368000 bigL: 184 freq: 231.3304721030043
# i: 376000 bigL: 216 freq: 206.16234594135145
# i: 384000 bigL: 176 freq: 245.86923466801824
# i: 392000 bigL: 200 freq: 221.60804020100505
# i: 400000 bigL: 152 freq: 277.0416904625928
# i: 408000 bigL: 176 freq: 260.94674556213016
# i: 424000 bigL: 152 freq: 277.0416904625928
# i: 432000 bigL: 152 freq: 275.78169414440026
# i: 440000 bigL: 168 freq: 256.25990491283676
# i: 448000 bigL: 176 freq: 244.87632508833923
# i: 456000 bigL: 200 freq: 223.65145228215766
# i: 464000 bigL: 168 freq: 250.95706156233837
# i: 472000 bigL: 176 freq: 247.37378888322283
# i: 488000 bigL: 176 freq: 251.47744945567652
# i: 496000 bigL: 184 freq: 240.02968827313214
# i: 504000 bigL: 184 freq: 228.49740932642484
# done!

# %%
plt.plot(Diner.real_freq)

# %%
Diner.build_output(mod_type='identity')
Diner.play()

# %%
Diner.build_output(mod_type='constant', freq=212)
Diner.play()

# %%
Diner.build_output(mod_type='linear', start_freq=60, end_freq=300)
Diner.play()

# %%
Diner.build_output('vibrato', vib_freq=15, amp=20)
Diner.play()

# %% [markdown]
# ## Custom Edit
#
#
# <H3 align="center">Believe - Cher </H3>
# <img src="presentation/Cher.png" alt="drawing" width="600" align="center"/>

# %%
fs, Cher = wavfile.read('presentation/Cher_LAL.wav')
sd.play(Cher,fs)

# %%
fs, lifeAfterLove = wavfile.read('samples/lifeafterlove.wav')
LAL = AutoTune(lifeAfterLove, sensitivity=.015, min_freq=100, max_freq=220, preserve_orig_on_fail=True)
# Out:
# (763090,)
# i: 48000 bigL: 304 freq: 144.5040214477212
# i: 56000 bigL: 352 freq: 124.73643610182565
# i: 64000 bigL: 352 freq: 124.28900845503459
# i: 72000 bigL: 344 freq: 125.9672812256557
# i: 80000 bigL: 344 freq: 127.42316784869978
# i: 88000 bigL: 280 freq: 162.73062730627305
# i: 96000 bigL: 208 freq: 211.37254901960785
# i: 104000 bigL: 208 freq: 212.66988163086364
# i: 112000 bigL: 248 freq: 174.55919395465997
# i: 120000 bigL: 224 freq: 192.882703777336
# i: 128000 bigL: 232 freq: 191.05947223316267
# i: 136000 bigL: 224 freq: 190.6090373280943
# i: 144000 bigL: 224 freq: 198.40490797546013
# i: 152000 bigL: 216 freq: 198.567335243553
# i: 160000 bigL: 248 freq: 178.14910025706942
# i: 168000 bigL: 352 freq: 122.1606648199446
# i: 176000 bigL: 232 freq: 193.3439617377441
# i: 184000 bigL: 360 freq: 119.51219512195122
# i: 192000 bigL: 232 freq: 182.9875518672199
# i: 200000 bigL: 216 freq: 197.75784753363226
# i: 208000 bigL: 216 freq: 196.00000000000003
# i: 216000 bigL: 216 freq: 213.04347826086956
# i: 224000 bigL: 216 freq: 213.04347826086956
# i: 232000 bigL: 216 freq: 213.04347826086956
# i: 240000 bigL: 216 freq: 196.00000000000003
# i: 248000 bigL: 216 freq: 199.05621665982764
# i: 256000 bigL: 216 freq: 213.04347826086956
# i: 264000 bigL: 216 freq: 213.04347826086956
# i: 272000 bigL: 216 freq: 196.00000000000003
# i: 280000 bigL: 216 freq: 202.71625574592565
# i: 288000 bigL: 216 freq: 213.04347826086956
# i: 296000 bigL: 216 freq: 207.21913712088852
# i: 312000 bigL: 296 freq: 150.60540204905308
# i: 320000 bigL: 216 freq: 200.3717472118959
# i: 328000 bigL: 272 freq: 163.6087689713322
# i: 336000 bigL: 264 freq: 168.1455805892548
# i: 344000 bigL: 264 freq: 166.9879518072289
# i: 352000 bigL: 216 freq: 197.91921664626685
# i: 360000 bigL: 344 freq: 126.691042047532
# i: 368000 bigL: 304 freq: 149.4915254237288
# i: 376000 bigL: 256 freq: 173.3118971061093
# i: 384000 bigL: 256 freq: 170.38988408851424
# i: 392000 bigL: 280 freq: 162.73062730627305
# i: 400000 bigL: 328 freq: 135.31380753138075
# i: 416000 bigL: 240 freq: 187.369640787949
# i: 424000 bigL: 224 freq: 196.9549330085262
# i: 432000 bigL: 224 freq: 193.0362116991643
# i: 440000 bigL: 216 freq: 205.4637865311309
# i: 448000 bigL: 216 freq: 201.20282040647035
# i: 456000 bigL: 248 freq: 180.26755852842808
# i: 464000 bigL: 248 freq: 171.5953307392996
# i: 472000 bigL: 216 freq: 212.29759299781185

# %%
plt.plot(LAL.real_freq)

# %%
plt.plot(LAL.real_freq)

# %%
LAL.build_output(mod_type='identity')
LAL.play()

# %%
des = np.ones_like(LAL.real_freq)*130.81 # C do you be
des[85000:] = 220.00 #A3 leive
des[95000:] = 196.00 #G3 in
des[150000:170000] = 174.61 #F3 life
des[250000:] = 174.61 #F3
des[350000:360000] = 130.81
des[380000:] = 130.81
des[400000:] = 196.00 #G3
des[455000:500000] = 174.61 #F3
des[550000:570000] = 174.61 #F3
des[585000:600000] = 220.00 #A3
dn = np.linspace(220.00, 174.61, 5000)
des[620000:] = 220.00 #A3
des[630000:] = 174.61 #F3
des[630000:630000+5000]=dn
LAL.build_output(mod_type='custom', desired=des)
sd.play(LAL.output.astype(np.float64)/max(LAL.output), 44100)

# %%
des = np.ones_like(LAL.real_freq)*130.81*2
des[85000:] = 220.00*2 #A3
des[95000:] = 196.00*2 #G3
des[150000:170000] = 174.61*2 #F3
des[250000:] = 174.61*2 #F3
des[350000:360000] = 130.81*2
des[380000:] = 130.81*2
des[400000:] = 196.00*2 #G3
des[455000:500000] = 174.61*2 #F3
des[550000:570000] = 174.61*2 #F3
des[585000:600000] = 220.00*2 #A3
dn = np.linspace(220.00*2, 174.61*2, 5000)
des[620000:] = 220.00*2 #A3
des[630000:] = 174.61*2 #F3
des[630000:630000+5000]=dn
LAL.build_output(mod_type='custom', desired=des)
sd.play(LAL.output, 44100)
sd.play(LAL.output.astype(np.float64)/max(LAL.output), 44100)
