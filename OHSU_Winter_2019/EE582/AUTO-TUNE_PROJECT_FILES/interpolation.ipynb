# %%
# https://docs.scipy.org/doc/scipy/reference/tutorial/interpolate.html

import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# %%
x = np.linspace(-4, 4, num=9, endpoint=True)
y = np.array([45,43,42,44,47,49, 50, 50,49])

# %%
plt.plot(x,y)

# %%
smth = interp1d(x,y, kind='cubic')
new_x = np.linspace(-4, 4, num=90, endpoint=True)

# %%
plt.plot(new_x, smth(new_x))

# %%
inter_x = smth(new_x)
print(inter_x.shape)
print(new_x[int(np.argmin(inter_x))])
float(np.argmin(inter_x))*float(len(x))/float(len(inter_x))
# Out:
# (90,)
# -2.1123595505617976
# 2.1

# %%
print(inter_x[:30])
# Out:
# [45.         44.85832001 44.70241415 44.53448544 44.35673692 44.1713716
#  43.98059253 43.78660272 43.59160521 43.39780302 43.20739919 43.02259674
#  42.8455987  42.67860809 42.52382795 42.38346131 42.25971118 42.15478061
#  42.07087262 42.01019024 41.97493649 41.9673144  41.98952701 42.04346073
#  42.1282463  42.24159559 42.38120872 42.54478585 42.73002709 42.93463259]

# %%
## build function to use
def get_real_freq(down_indx, down_f_est):
            real_indx = 8*down_indx
            real_f_est = 8*down_f_est
            real_line = np.linspace(real_indx-9,real_indx+9,19, dtype=int)
            real_sub = np.zeros(len(real_line), dtype=float)
            print(real_line)

# %%
get_real_freq(44,44)
# Out:
# [343 344 345 346 347 348 349 350 351 352 353 354 355 356 357 358 359 360
#  361]
