# %%
import pandas as pd
import pickle

# %%
header = ["Count","Index","Name","Prefix","Date Joined","Date of Last Deposit","Date of Last Query"]

table = pd.read_csv('count_output.csv', names=header)
table.sort_values(by=["Count"], ascending=False)
# Out:
#       Count  Index                                               Name  \
# 1   9296486   1561                                           Elsevier
# 7   2621957   5237                                    Springer-Verlag
# 8   2621957   5239                                    Springer-Verlag
# 3   2138064   2346  Institute of Electrical and Electronics Engineers
# 0   1871934    189                          American Chemical Society
# 12  1367250   6758                Wiley Blackwell (John Wiley & Sons)
# 4   1121881   4159                            Nature Publishing Group
# 5   1121881   4161                            Nature Publishing Group
# 9    927239   6119                     The Royal Society of Chemistry
# 2    906221   2254                      Informa UK (Taylor & Francis)
# 10   814996   6748             Wiley Blackwell (Blackwell Publishing)
# 11   814996   6750             Wiley Blackwell (Blackwell Publishing)
# ...
